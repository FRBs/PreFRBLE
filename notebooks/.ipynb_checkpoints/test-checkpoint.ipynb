# %%
import h5py as h5
from PreFRBLE.convenience import *
from PreFRBLE.plot import *

# %%
import sympy as sym
from sympy import *
from IPython.display import display

# %%
Th, th, t, z, a, b = symbols("Theta theta t z a b")
rx, ry, Lx, Ly = symbols("r_x r_y L_x L_y")


assuming( z < a, a < b)
#th=10

r = [ a*sin(Th), b*cos(Th) ]
L = [ t*sin(th) + z*cos(th), t*cos(th) - z*sin(th) ]

#display( rx, r[0])
#display( ry, r[1])
#display( Lx, L[0])
#display( Ly, L[1])

## find solutions, where r = L

# %%
solutions = solve( [r[i]-L[i] for i in range(len(L))], (th,) )
## works better when reduced by hand to the following
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-2c45cb206c5e> in <module>()
# ----> 1 solutions = solve( [r[i]-L[i] for i in range(len(L))], (th,) )
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1171         solution = _solve(f[0], *symbols, **flags)
#    1172     else:
# -> 1173         solution = _solve_system(f, symbols, **flags)
#    1174
#    1175     #
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/solvers/solvers.py in _solve_system(exprs, symbols, **flags)
#    1916                 for s in ok_syms:
#    1917                     try:
# -> 1918                         soln = _solve(eq2, s, **flags)
#    1919                     except NotImplementedError:
#    1920                         continue
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1576                         # solutions in the un-rewritten form below
#    1577                         flags['check'] = False
# -> 1578                         result = _solve(newf, symbol, **flags)
#    1579                         flags['check'] = check
#    1580
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1743
#    1744     if flags.get('simplify', True):
# -> 1745         result = list(map(simplify, result))
#    1746         # we just simplified the solution so we now set the flag to
#    1747         # False so the simplification doesn't happen again in checksol()
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse)
#     580
#     581     if expr.has(TrigonometricFunction, HyperbolicFunction):
# --> 582         expr = trigsimp(expr, deep=True)
#     583
#     584     if expr.has(log):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/simplify/trigsimp.py in trigsimp(expr, **opts)
#     506                    }[method]
#     507
# --> 508     return trigsimpfunc(expr)
#     509
#     510
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#     499     trigsimpfunc = {
#     500         'fu': (lambda x: fu(x, **opts)),
# --> 501         'matching': (lambda x: futrig(x)),
#     502         'groebner': (lambda x: groebnersimp(x, **opts)),
#     503         'combined': (lambda x: futrig(groebnersimp(x,
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/simplify/trigsimp.py in futrig(e, **kwargs)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1085             if args != rv.args:
#    1086                 rv = rv.func(*args)
# -> 1087             rv = F(rv)
#    1088         elif atoms:
#    1089             rv = F(rv)
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#    1099
#    1100     old = e
# -> 1101     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    1102
#    1103     if kwargs.pop('hyper', True) and e.has(HyperbolicFunction):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/simplify/trigsimp.py in _futrig(e, **kwargs)
#    1167             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1168         )]
# -> 1169     e = greedy(tree, objective=Lops)(e)
#    1170     return coeff*e
#    1171
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/strategies/core.py in minrule(expr)
#     115     objective = kwargs.get('objective', identity)
#     116     def minrule(expr):
# --> 117         return min([rule(expr) for rule in rules], key=objective)
#     118     return minrule
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/strategies/core.py in <listcomp>(.0)
#     115     objective = kwargs.get('objective', identity)
#     116     def minrule(expr):
# --> 117         return min([rule(expr) for rule in rules], key=objective)
#     118     return minrule
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/strategies/core.py in chain_rl(expr)
#      42     def chain_rl(expr):
#      43         for rule in rules:
# ---> 44             expr = rule(expr)
#      45         return expr
#      46     return chain_rl
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/strategies/core.py in minrule(expr)
#     115     objective = kwargs.get('objective', identity)
#     116     def minrule(expr):
# --> 117         return min([rule(expr) for rule in rules], key=objective)
#     118     return minrule
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/simplify/trigsimp.py in <lambda>(x)
#    1127         coeff = S.One
#    1128
# -> 1129     Lops = lambda x: (L(x), x.count_ops(), _nodes(x), len(x.args), x.is_Add)
#    1130     trigs = lambda x: x.has(TrigonometricFunction)
#    1131
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/compatibility.py in _nodes(e)
#     589
#     590     if isinstance(e, Basic):
# --> 591         return e.count(Basic)
#     592     elif iterable(e):
#     593         return 1 + sum(_nodes(ei) for ei in e)
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/basic.py in count(self, query)
#    1522         """Count the number of matching subexpressions. """
#    1523         query = _make_find_query(query)
# -> 1524         return sum(bool(query(sub)) for sub in preorder_traversal(self))
#    1525
#    1526     def matches(self, expr, repl_dict={}, old=False):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/basic.py in <genexpr>(.0)
#    1522         """Count the number of matching subexpressions. """
#    1523         query = _make_find_query(query)
# -> 1524         return sum(bool(query(sub)) for sub in preorder_traversal(self))
#    1525
#    1526     def matches(self, expr, repl_dict={}, old=False):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/basic.py in __next__(self)
#    2005
#    2006     def __next__(self):
# -> 2007         return next(self._pt)
#    2008
#    2009     def __iter__(self):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/basic.py in _preorder_traversal(self, node, keys)
#    1976                     args = ordered(args)
#    1977             for arg in args:
# -> 1978                 for subtree in self._preorder_traversal(arg, keys):
#    1979                     yield subtree
#    1980         elif iterable(node):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/basic.py in _preorder_traversal(self, node, keys)
#    1976                     args = ordered(args)
#    1977             for arg in args:
# -> 1978                 for subtree in self._preorder_traversal(arg, keys):
#    1979                     yield subtree
#    1980         elif iterable(node):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/basic.py in _preorder_traversal(self, node, keys)
#    1976                     args = ordered(args)
#    1977             for arg in args:
# -> 1978                 for subtree in self._preorder_traversal(arg, keys):
#    1979                     yield subtree
#    1980         elif iterable(node):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/basic.py in _preorder_traversal(self, node, keys)
#    1976                     args = ordered(args)
#    1977             for arg in args:
# -> 1978                 for subtree in self._preorder_traversal(arg, keys):
#    1979                     yield subtree
#    1980         elif iterable(node):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/basic.py in _preorder_traversal(self, node, keys)
#    1976                     args = ordered(args)
#    1977             for arg in args:
# -> 1978                 for subtree in self._preorder_traversal(arg, keys):
#    1979                     yield subtree
#    1980         elif iterable(node):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/sympy/core/basic.py in _preorder_traversal(self, node, keys)
#    1976                     args = ordered(args)
#    1977             for arg in args:
# -> 1978                 for subtree in self._preorder_traversal(arg, keys):
#    1979                     yield subtree
#    1980         elif iterable(node):
#
# KeyboardInterrupt:

# %%
sol = solve( a*sin(Th) - b*cos(Th) - z, Th )

# %%
for s in sol:
    display(s.subs(b,b*sin(th)).subs(a,a*cos(th)))
# Out:
# -2*atan((a*cos(theta) - sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))
# -2*atan((a*cos(theta) + sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))

# %%
rr = [[0,0],[0,0]]
for i, s in enumerate(sol):
    ss = s.subs(b,b*sin(th)).subs(a,a*cos(th))
    rr[i][0] = r[0].subs(Th, ss)
    rr[i][1] = r[1].subs(Th, ss)
print( "path length of LoS within ellipse" )
display(sqrt(  (rr[0][0] - rr[1][0] )**2 + (rr[0][1] - rr[1][1] )**2 ) )
# Out:
# path length of LoS within ellipse
# sqrt((-a*sin(2*atan((a*cos(theta) - sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))) + a*sin(2*atan((a*cos(theta) + sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))))**2 + (b*cos(2*atan((a*cos(theta) - sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))) - b*cos(2*atan((a*cos(theta) + sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))))**2)

# %%
display(simplify(sqrt(  (rr[0][0] - rr[1][0] )**2 + (rr[0][1] - rr[1][1] )**2 )))
# Out:
# sqrt(a**2*(sin(2*atan((a*cos(theta) - sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))) - sin(2*atan((a*cos(theta) + sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))))**2 + b**2*(cos(2*atan((a*cos(theta) - sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))) - cos(2*atan((a*cos(theta) + sqrt(a**2*cos(theta)**2 + b**2*sin(theta)**2 - z**2))/(b*sin(theta) - z))))**2)

# %%
def WeighBayes( B, w ):
    w_log = np.log10(w)
    return 10.**( np.log10(B) * (1+np.abs(w_log))**(1 - 2*(w_log<0) - (w_log==0) )  )

# %%
WeighBayes( 10.**np.arange(-3,4), 0.01 )
# Out:
# array([ 0.1       ,  0.21544347,  0.46415888,  1.        ,  2.15443469,
#         4.64158883, 10.        ])

# %%
def f(x):
    return [x], [x]

a=np.array([1,2,3])
b=[1,2,3]

[a[0]], [b[0]] = f(1)
print(a,b)

def f(x):
    return x, x


for x in range(4):
    a, b = f(x) if x < 2 else (1,2)
    print(a,b)
    

def f(x):
    res = [x,x]
    return res[:1+(x>1)]
a = map( f, range(3) )
for i in a:
    print(i)
# Out:
# [1 2 3] [1, 2, 3]
# 0 0
# 1 1
# 1 2
# 1 2
# [0]
# [1]
# [2, 2]

# %%
non = None

len(non)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-c8591c934c04> in <module>()
#       1 non = None
#       2
# ----> 3 len(non)
#
# TypeError: object of type 'NoneType' has no len()

# %%
from matplotlib.cm import YlGn

def Gradient( x=np.linspace(0,1,2), min=None, max=None ):
    """ return rainbow colors for 1D array x """
    if min is None:
        min = x.min()
    if max is None:
        max = x.max()-min
    else:
        max -= min
    x_ = x - min
    x_ /= max
    return YlGn( x_ )

# %%
N = 100
y = np.linspace(-5,0,N)
colors = Gradient(y)

for yy, c in zip(y, colors):
    plt.plot( [0,1], [1e-3,yy], color=c )

# %%
for x in np.arange(1,100):
    p.Process( np.sin, x )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-a5c4bad377d1> in <module>()
#       1 for x in np.arange(1,100):
# ----> 2     p.Process( np.sin, x )
#
# /usr/lib/python3.4/multiprocessing/pool.py in Process(self, *args, **kwds)
#     143
#     144     def Process(self, *args, **kwds):
# --> 145         return self._ctx.Process(*args, **kwds)
#     146
#     147     def __init__(self, processes=None, initializer=None, initargs=(),
#
# /usr/lib/python3.4/multiprocessing/process.py in __init__(self, group, target, name, args, kwargs, daemon)
#      71     def __init__(self, group=None, target=None, name=None, args=(), kwargs={},
#      72                  *, daemon=None):
# ---> 73         assert group is None, 'group argument must be None for now'
#      74         count = next(_process_counter)
#      75         self._identity = _current_process._identity + (count,)
#
# AssertionError: group argument must be None for now

# %%
B0 = (3*1.96e-7**2)**(1./2)  # Gauss
z0 = 60
print( B0, 1e-9 / ( B0/(1+z0)**2 ) , "Gauss")
# Out:
# 3.3948195828349994e-07 10.960818120686723 Gauss

# %%
a = np.arange(0.1,6.0,0.1)
a[9:30:10]
# Out:
# array([1., 2., 3.])

# %%
N=100
n=np.arange(N)/5
a=np.arange(N).repeat(3).reshape(N,3)

a = np.array([np.sin(n), np.cos(n), np.sin(n)*np.cos(n)]).transpose()

x = np.round(np.arange(0.5,1.4,0.1),1)
y = np.arange(-1,2)
y_labels = ['A','B','C']


plt.imshow( a, cmap=rainbow, extent=[0,30,0,50] )
plt.xticks( [5,15,25], y_labels )
plt.yticks( np.linspace(2,48,len(x)), x )
# Out:
# ([<matplotlib.axis.YTick at 0x7fa4c73f4400>,
#   <matplotlib.axis.YTick at 0x7fa4c73f2cf8>,
#   <matplotlib.axis.YTick at 0x7fa4c73fba20>,
#   <matplotlib.axis.YTick at 0x7fa4c7408dd8>,
#   <matplotlib.axis.YTick at 0x7fa4c740b320>,
#   <matplotlib.axis.YTick at 0x7fa4c740b828>,
#   <matplotlib.axis.YTick at 0x7fa4c740bd30>,
#   <matplotlib.axis.YTick at 0x7fa4c7410278>,
#   <matplotlib.axis.YTick at 0x7fa4c740be10>],
#  <a list of 9 Text yticklabel objects>)

# %%
plt.imshow?
from matplotlib.colors import LogNorm
LogNorm?

# %%
plt.imshow(np.random.rand(3,50), aspect='equal', extent=[0,50,0,50])

# %%
from astropy import units as u
from astropy.coordinates import SkyCoord, Distance
from astropy.cosmology import Planck15
from scipy import integrate

z1 = 0.01

dist1 = Distance(unit=u.pc, z = z1, cosmology = Planck15)

dist1.pc
# Out:
# 44595101.92007588

# %%
rho_crit = Planck15.critical_density0.value # g/cm3
omega_b = Planck15.Ob0
omega_m = Planck15.Om0
omega_L = Planck15.Ode0
m_p = 1.67e-24 # g
mu_e = 1.16
c = 2.99e8 # m/s
H_0 = 1./Planck15.hubble_time.value

n_e = rho_crit * omega_b  / m_p / mu_e

def DM(z, f_IGM=0.82):
    return n_e * f_IGM *c/H_0* integrate.quad( lambda z: (1+z)/( omega_m*(1+z)**3 + omega_L )**0.5, 0, z)[0]
    #return n_e * f_IGM * Distance( unit=u.pc, z = z, cosmology = Planck15).parsec

# %% [markdown]
# check here that $C$ in $DM(z|C) = C\times z \times 1000$ pc cm$^{-3}$ is indeed $f_{\rm IGM}$: compare expectation according to $f_{\rm IGM}$ (solid, see equation above) to $DM(z|f_{\rm IGM})$ (dotted). The two cases are identical until redshift $z=3$, where the assumption of fully ionized helium might break as well.

# %%
zs = np.linspace(0.1,6,60)
ps = np.arange(0.5,1.1,0.1)[::2]
f_IGM0s = np.arange( 0.3,1.0,0.1 )
for p, color in zip( ps, Rainbow(ps) ):
    DMs = [ DM(z, f_IGM=p) for z in zs ]
#    plt.plot(zs, DMs/(zs*1000*p), color=color)
    plt.plot(zs, DMs, color=color)
    plt.plot( zs, zs*1000*p, color=color, linestyle=":")
plt.yscale('log')
#plt.xlim(0,1)
Colorbar( ps, label=r"$f_{\rm IGM}$" )

# %% [markdown]
# Simulations show that at $z \gtrsim 1.5$ about 90 % of baryons were contained in the IGM (Meiskin 2008, 0711.3358). Here we check how much results for a linear evolution of $f_{\rm IGM}$ between redshifts $z=1.5$ and $z=0$ (solid) would differ from constant $f_{\rm IGM}$ (dotted). The right plot shows the ratio of the two graphs.

# %%
zs = np.linspace(0.1,6,60)
ps = np.arange(0.5,1.1,0.1)[::2]
p = 1
f_IGM0s = np.arange( 0.3,1.0,0.1 )

fig, axs = plt.subplots(1,2, figsize=(8,3))

for f_IGM0, color in zip( f_IGM0s, Rainbow(f_IGM0s) ):
    f_IGMs = f_IGM0 + np.where( zs<1.5, zs, 1.5)/1.5 * 0.50
    DMs = [ DM(z, f_IGM=f_IGM) for z, f_IGM in zip( zs, f_IGMs ) ]
    axs[1].plot(zs, DMs/(zs*1000*f_IGM0), color=color)
    axs[0].plot(zs, DMs, color=color)
    axs[0].plot( zs, zs*1000*f_IGM0, color=color, linestyle=":")
for ax in axs:
    ax.set_xlim(0,3)
axs[0].set_yscale('log')
Colorbar( f_IGM0s, label=r"$f_{\rm IGM}$" )

# %%
import DM_Hackstein

# %%
LoS = DM_Hackstein.Sightline( 1, 1e-3 )

# %%
z, DM, RM = HowLong( LoS.MC_DM_RM, 1, 0.01, 3, 6 ) 

plt.plot(z,DM)
plt.yscale('log')
plt.show()
plt.plot(z,np.abs(RM))
plt.yscale('log')
plt.show()
# Out:
# 0.0  %
# 16.666666666666668  %
# 33.333333333333336  %
# 50.0  %
# 66.66666666666667  %
# 83.33333333333333  %
# this took 346 seconds or 5.8 minutes

# %%
zs, dens = LoS.CreateArrays( 3.0 )
DMs = HowLong( LoS.DispersionMeasure, dens, zs )
plt.plot( zs, DMs)
plt.yscale('log')
# Out:
# this took 103 seconds or 1.7 minutes

# %%
z_max = 0.01
t0 = time()

def next(z):
    return z + JeansLength(z)

za = np.array([0])
z=0.
while z<z_max:
    z = next(za[-1])
    za = np.append(za,z)

#za = [ lambda z: z + JeansLength(z) while z < z_max ]

print(za)


t1 = time()

za = np.array([0])
z=0.
while z<z_max:
    z = za[-1] + JeansLength(za[-1])
    za = np.append(za,z)
print(za)
t2 = time()

print( "first was %f faster" % ( (t2-t1)/(t1-t0) )  )
# Out:
# [0.         0.0005199  0.00103979 0.00155967 0.00207953 0.00259939
#  0.00311924 0.00363908 0.00415891 0.00467873 0.00519855 0.00571835
#  0.00623815 0.00675794 0.00727772 0.00779749 0.00831726 0.00883702
#  0.00935677 0.00987651 0.01039624]
# [0.         0.0005199  0.00103979 0.00155967 0.00207953 0.00259939
#  0.00311924 0.00363908 0.00415891 0.00467873 0.00519855 0.00571835
#  0.00623815 0.00675794 0.00727772 0.00779749 0.00831726 0.00883702
#  0.00935677 0.00987651 0.01039624]
# first was 0.988528 faster

# %%
from astropy.cosmology import Planck15, z_at_value
import astropy.units as u
def JeansLength(z):
    """                                                                                                                     
    Computes Jeans length in unitless Delta z                                                                               
    lambda_J=2.3 Mpc (1+z)^-3/2 Pshirkov 2016                                                                               
    """
    dist=Planck15.lookback_distance(z).value # in Mpc                                                                       
    jeanslength=2.3*(1+z)**(-1.5)              # in Mpc                                                                     
    z1=z_at_value(Planck15.lookback_distance,(dist+jeanslength)*u.Mpc)
    return z1-z

# %%
N = 10
print( 100.*(2*N+1)/60 )
# Out:
# 35.0

# %%
a = range(5)
l = []
for i, j in zip(a,a[1:]):
    l.append( [i,j])

# %%
np.array(l).shape
# Out:
# (4, 2)
