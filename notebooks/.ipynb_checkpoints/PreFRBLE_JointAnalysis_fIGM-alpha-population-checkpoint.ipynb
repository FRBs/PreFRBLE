# %%
from PreFRBLE.convenience import *
from PreFRBLE.estimate_redshift import *
from PreFRBLE.plot import *
from PreFRBLE.likelihood import *
from PreFRBLE.physics import *
from PreFRBLE.sample import *

# %%
scenario = {
    'IGM' : ['primordial'],
    'Host' : ['Rodrigues18'],
#    'Inter' : ['Rodrigues18'],
    'Local' : ['Piro18/wind'],
}

scenario_test = {
    'IGM' : ['primordial'],
    'Host': ['JF12/StarDensity_MW'],
    'Local': ['Piro18/wind'], 
}

scenario_test = {
    'IGM' : ['primordial'],
    'Host': ['Heesen11/dirty'],
    'Local': ['Piro18/wind'], 
}


scenario0 = {
    'IGM' : ['primordial'],
    'Host': ['JF12/StarDensity_MW'],
    'Local': ['Piro18/wind'], 
}

scenario_IGM = {
    'IGM' : ['primordial'],
}

f_IGMs = np.arange(0.300,0.901, 0.100)
alphas = np.arange(1.,9.1,1.0)/3

# %%
RM = np.abs(FRBs['RM'])
RM = RM[RM>0]
RM.min(), RM.max()
# Out:
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in greater
# (1.5, 220.6)

# %%
observed_range = {
    'DM' : (1e1,1e4),
    'RM' : (1e-1,1e3),
    
}
    
    
def LikelihoodObservedMeasure( measure='DM', scenario={}, telescope='Parkes', population='SMD', FRBs=None, Measures=None, use_localized=True, plot=False, plot_FRBs=False, ax=None, label=None, title=None, force=False ):
    """ 
    returns likelihood of values of DM observed by telescope for the case of scenario and population
    
    Parameters
    ----------
    FRBs : array-like
        list of FRBs observed by telescope, result of GetFRBcat( telescopes=[telescope] )
    
    Returns
    -------
    likelihoods : array-like
        1D array with likelihoods of individual DM observed by telescope  
    """

    P_M, M = GetLikelihood_Telescope( measure=measure, telescope=telescope, population=population, force=force, **scenario )
        
    if Measures is None:
        ## read observed values of extragalactic DM
        if FRBs is None:
            FRBs = GetFRBcat( telescopes=[telescope] )
        Measures = GetFRBsMeasures( measure=measure, FRBs=FRBs )
    if plot:
        if ax is None:
            fig, ax = plt.subplots()
        if title is None:
            title = "%s with %s" % (population, telescope)
        ax.set_title( title )
        PlotLikelihood( P=P_M, x=M, measure=measure, label=label, ax=ax )
        
        if plot_FRBs:
            P_, x_ = Histogram( data=np.abs(Measures), bins=10, log=True, density=True, range=observed_range[measure] )#, range=(1e1,1e4) )
            PlotLikelihood( P=P_, x=x_, measure=measure, ax=ax, label="observed", linestyle='-.', color='black' )
#        AllSidesTicks( ax )
    
    ## compute likelihood of observation
    likelihoods = Likelihoods( measurements=Measures, P=P_M, x=M )
    
    ## for FRBs with localized host, use likelihood for DM from that redshift, P(DM|z_host), instead
    if use_localized:
        localized, = np.where( FRBs['host_redshift']>0 )
        for loc in localized:
            z_host = np.round(FRBs[loc]['host_redshift'],1)
            
            P_z, z = GetLikelihood_Redshift( population=population, telescope=telescope )
            P_M, M = GetLikelihood_Full( measure=measure, redshift=z_host, force=force, **scenario )
            
            ## likelihood for host redshift in population 
            prior = Likelihoods( measurements=[z_host], P=P_z, x=z ) ##**( 1 - (telescope in ['ASKAP']) )  ## ignore redhift prior for these telescope, since they are not informative for population
            ## multiply by likelihood for DM at host redshift
            likelihoods[loc], = Likelihoods( measurements=[Measures[loc]], P=P_M, x=M ) * prior 

        if plot_FRBs:
            y_Measures = 0.75-0.5*np.random.rand( len(localized) )
            ax.plot( Measures[localized], y_Measures, marker='x', linestyle=' ' )
    return likelihoods

# %%
#fig, axss = plt.subplots( 2, 3, figsize=(12,6), sharex=True, sharey=True)
for alpha in [1, 9]:
    fig, axss = plt.subplots( 2, 3, figsize=(12,6), sharex=True, sharey=True)
    for f_IGM, axs in zip( f_IGMs[np.array([0,-1])], axss ):
        tmp = scenario_test.copy()
        tmp['IGM'] = ['alpha%i-3rd_C%.0f' % (alpha, f_IGM*1000)]
        print(tmp)
        for telescope, ax in zip( telescopes, axs):
#            ax.set_xlim(1e-3,1e3)
            ax.set_ylim(1e-3,1.5)
            #ax.set_ylim(1e-5,1.5)
            ax.set_title( r"%s, $f_{\rm IGM}$=%.1f" % (telescope, f_IGM) )
            for population in populations:
#                P, x = GetLikelihood_Telescope( measure='RM', telescope=telescope, population=population, force=False, **tmp )
#                PlotLikelihood( P=P, x=x,label=population, ax=ax )
                LikelihoodObservedMeasure( force=False, measure='RM', scenario=tmp, telescope=telescope, population=population, plot=True, ax=ax, plot_FRBs=population == populations[-1], label=population, title=r"%s, $f_{\rm IGM}$=%.1f" % (telescope, f_IGM) )
            AllSidesTicks(ax)
    axss[1][1].legend()
    fig.tight_layout()
    plt.show()
#axss[1][1].legend()
#fig.tight_layout()
#plt.show()
# Out:
# {'IGM': ['alpha1-3rd_C300'], 'Local': ['Piro18/wind'], 'Host': ['Heesen11/dirty']}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-f217f701a8c6> in <module>()
#      14 #                P, x = GetLikelihood_Telescope( measure='RM', telescope=telescope, population=population, force=False, **tmp )
#      15 #                PlotLikelihood( P=P, x=x,label=population, ax=ax )
# ---> 16                 LikelihoodObservedMeasure( force=False, measure='RM', scenario=tmp, telescope=telescope, population=population, plot=True, ax=ax, plot_FRBs=population == populations[-1], label=population, title=r"%s, $f_{\rm IGM}$=%.1f" % (telescope, f_IGM) )
#      17             AllSidesTicks(ax)
#      18     axss[1][1].legend()
#
# <ipython-input-3-c6de55c2f9b7> in LikelihoodObservedMeasure(measure, scenario, telescope, population, FRBs, Measures, use_localized, plot, plot_FRBs, ax, label, title, force)
#      43
#      44     ## compute likelihood of observation
# ---> 45     likelihoods = Likelihoods( measurements=Measures, P=P_M, x=M )
#      46
#      47     ## for FRBs with localized host, use likelihood for DM from that redshift, P(DM|z_host), instead
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in Likelihoods(measurements, P, x, dev, minimal_likelihood)
#      80                 ## put result in correct place and stop checking bins
#      81                 likelihoods[i_s] = Pdx[i-1]  if i > 0 else minimal_likelihood  ## if that was the lowest bound, probability is ->zero if measurement is outside the range of P, i. e. P~0
# ---> 82                 deviations[i_s] = dev[i-1] if i > 0 else 1
#      83                 break    ## continue with the next measurement
#      84         else:
#
# IndexError: list index out of range

# %%
#fig, axss = plt.subplots( len(alphas), len(f_IGMs), figsize=(len(f_IGMs)*4, len(models_IGM[3:])*3), sharex=True, sharey=True )
fig, axss = plt.subplots( 2, 2, figsize=(8,6), sharex=True, sharey=True )
#for i_a, model in enumerate( np.array(models_IGM[3:])[np.array([0,-1])] ):
for i_a, alpha in enumerate( alphas[np.array([0,-1])] ):
    for i_f, f_IGM in enumerate( np.array(f_IGMs)[np.array([0,-1])] ):
        tmp = scenario_IGM.copy()
        tmp['IGM'] = ['alpha%i-3rd_C%.0f' % (int(alpha*3), f_IGM*1000)]
        print(tmp)
        ax = axss[i_a][i_f]
        PlotLikelihoodEvolution( measure='RM', measureable=True, ax=ax, scenario=tmp, redshift_bins=redshift_bins[::10] )
        ax.set_ylim(1e-4,1)
# Out:
# {'IGM': ['alpha1-3rd_C300']}
# {'IGM': ['alpha1-3rd_C900']}
# {'IGM': ['alpha9-3rd_C300']}
# {'IGM': ['alpha9-3rd_C900']}

# %%
fig, axs = plt.subplots( len(telescopes), len(populations), figsize=(len(populations)*4, 3*len(telescopes)))


for i_t, telescope in enumerate(telescopes):
    for i_p, population in enumerate(populations):
        for i_a, alpha in enumerate( alphas[np.array([0,-1])] ):
            for i_f, f_IGM in enumerate( np.array(f_IGMs)[np.array([0,-1])] ):
                tmp = scenario_IGM.copy()
                tmp['IGM'] = ['alpha%i-3rd_C%.0f' % (int(alpha*3), f_IGM*1000)]
                PlotTelescope( measure='RM', telescope=telescope, population=population, ax=axs[i_p][i_t], label=r"$\alpha$ = %.0f/3, $f_{rm IGM}$ = %.1f" % (alpha*3,f_IGM), scenario=tmp)
        ax.set_ylim(1e-4,1)
        ax.legend()
        plt.show()

# %%
FRBs = GetFRBcat(telescopes=['ASKAP'])
FRBs[FRBs['host_redshift']>0]
# Out:
# array([('FRB181112', 589.27, 102. , 10.9, nan, 0.4755, 'ASKAP'),
#        ('FRB180924', 361.42,  40.5, 14. , nan, 0.3214, 'ASKAP')],
#       dtype=[('ID', '<U9'), ('DM', '<f4'), ('DM_gal', '<f4'), ('RM', '<f4'), ('tau', '<f4'), ('host_redshift', '<f4'), ('tele', '<U10')])

# %% [markdown]
# perform joint analysis using a mock sample of FRBs

# %%
N = 50 # number of FRBs

bayes_mock = np.zeros( [ len(populations), len(models_IGM[3:]), len(f_IGMs) ] )
population = 'SMD'
telescope = 'Parkes'


scenario_ref = scenario_test.copy()
scenario_ref['IGM'] = ['alpha3-3rd_C700']

print( scenario_ref)

FRBs_mock = FakeFRBs( measures=['DM','RM'], N=50, telescope=telescope, population=population, measureable=True, **scenario_test )# **scenario0 )
DMs = FRBs_mock['DM']
RMs = FRBs_mock['RM']
zs = FRBs_mock['redshift']

L0 = LikelihoodCombined( DMs=DMs, RMs=RMs, scenario=scenario_test, telescope=telescope, population=population )
for i_p, population in enumerate( populations ):
    for i_a, model in enumerate( models_IGM[3:] ):
        for i_f, f_IGM in enumerate( f_IGMs ):
            tmp = scenario_ref.copy()
            tmp['IGM'] = [ "%s_C%.0f" % ( model, f_IGM*1000 ) ]
            print(tmp)
            bayes_mock[i_p,i_a,i_f] = BayesFactorCombined( DMs=DMs, RMs=RMs, scenario1=tmp, scenario2=scenario0, population=population, telescope=telescope)
# Out:
# {'IGM': ['alpha3-3rd_C700'], 'Host': ['Heesen11/dirty'], 'Local': ['Piro18/wind']}
# ['primordial/Heesen11/dirty/Piro18/wind/0.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/6.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/6.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/6.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/6.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/6.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/6.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.0/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.1/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.1/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.2/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.2/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.3/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.3/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.4/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.4/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.5/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.5/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.6/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.6/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.7/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.7/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.8/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.8/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.9/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.9/RM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/6.0/RM/P', 'primordial/Heesen11/dirty/Piro18/wind/6.0/RM/x']
# {'IGM': ['alpha1-3rd_C500'], 'Host': ['Heesen11/dirty'], 'Local': ['Piro18/wind']}
# ['primordial/Heesen11/dirty/Piro18/wind/0.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/6.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/6.0/DM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.1/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.1/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.2/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.2/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.3/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.3/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.4/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.4/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.5/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.5/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.6/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.6/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.7/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.7/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.8/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.8/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.9/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/0.9/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.0/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.0/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.1/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.1/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.2/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.2/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.3/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.3/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.4/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.4/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.5/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.5/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.6/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.6/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.7/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.7/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.8/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.8/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.9/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/1.9/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.0/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.0/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.1/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.1/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.2/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.2/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.3/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.3/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.4/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.4/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.5/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.5/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.6/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.6/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.7/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.7/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.8/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.8/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.9/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/2.9/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.0/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.0/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.1/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.1/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.2/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.2/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.3/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.3/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.4/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.4/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.5/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.5/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.6/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.6/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.7/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.7/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.8/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.8/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.9/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/3.9/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.0/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.0/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.1/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.1/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.2/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.2/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.3/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.3/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.4/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.4/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.5/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.5/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.6/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.6/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.7/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.7/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.8/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.8/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.9/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/4.9/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.0/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.0/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.1/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.1/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.2/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.2/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.3/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.3/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.4/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.4/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.5/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.5/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.6/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.6/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.7/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.7/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.8/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.8/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.9/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/5.9/RM/x']
# ['alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/6.0/RM/P', 'alpha1-3rd_C500/Heesen11/dirty/Piro18/wind/6.0/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.1/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.1/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.2/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.2/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.3/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.3/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.4/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.4/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.5/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.5/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.6/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.6/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.7/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.7/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.8/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.8/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.9/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.9/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.0/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.0/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.1/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.1/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.2/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.2/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.3/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.3/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.4/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.4/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.5/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.5/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.6/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.6/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.7/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.7/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.8/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.8/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.9/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.9/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.0/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.0/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.1/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.1/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.2/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.2/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.3/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.3/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.4/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.4/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.5/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.5/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.6/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.6/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.7/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.7/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.8/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.8/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.9/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.9/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.0/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.0/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.1/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.1/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.2/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.2/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.3/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.3/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.4/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.4/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.5/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.5/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.6/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.6/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.7/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.7/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.8/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.8/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.9/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.9/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.0/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.0/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.1/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.1/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.2/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.2/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.3/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.3/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.4/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.4/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.5/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.5/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.6/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.6/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.7/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.7/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.8/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.8/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.9/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.9/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.0/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.0/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.1/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.1/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.2/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.2/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.3/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.3/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.4/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.4/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.5/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.5/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.6/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.6/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.7/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.7/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.8/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.8/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.9/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.9/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/6.0/DM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/6.0/DM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.1/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.1/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.2/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.2/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.3/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.3/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.4/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.4/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.5/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.5/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.6/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.6/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.7/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.7/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.8/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.8/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/0.9/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/0.9/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.0/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.0/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.1/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.1/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.2/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.2/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.3/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.3/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.4/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.4/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.5/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.5/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.6/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.6/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.7/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.7/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.8/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.8/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/1.9/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/1.9/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.0/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.0/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.1/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.1/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.2/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.2/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.3/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.3/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.4/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.4/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.5/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.5/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.6/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.6/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.7/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.7/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.8/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.8/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/2.9/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/2.9/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.0/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.0/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.1/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.1/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.2/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.2/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.3/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.3/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.4/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.4/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.5/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.5/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.6/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.6/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.7/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.7/RM/x']
# ...
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.4/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.4/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.5/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.5/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.6/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.6/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.7/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.7/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.8/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.8/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/3.9/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/3.9/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.0/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.0/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.1/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.1/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.2/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.2/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.3/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.3/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.4/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.4/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.5/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.5/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.6/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.6/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.7/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.7/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.8/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.8/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/4.9/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/4.9/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.0/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.0/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.1/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.1/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.2/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.2/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.3/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.3/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.4/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.4/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.5/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.5/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.6/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.6/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.7/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.7/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.8/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.8/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/5.9/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/5.9/RM/x']
# ['primordial/JF12/StarDensity_MW/Piro18/wind/6.0/RM/P', 'primordial/JF12/StarDensity_MW/Piro18/wind/6.0/RM/x']
# {'IGM': ['alpha2-3rd_C700'], 'Host': ['Heesen11/dirty'], 'Local': ['Piro18/wind']}
# ['primordial/Heesen11/dirty/Piro18/wind/0.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/0.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/0.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/1.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/1.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/2.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/2.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/3.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/3.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/4.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/4.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.0/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.1/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.1/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.2/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.2/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.3/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.3/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.4/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.4/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.5/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.5/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.6/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.6/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.7/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.7/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.8/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.8/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/5.9/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/5.9/DM/x']
# ['primordial/Heesen11/dirty/Piro18/wind/6.0/DM/P', 'primordial/Heesen11/dirty/Piro18/wind/6.0/DM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.1/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.1/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.2/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.2/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.3/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.3/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.4/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.4/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.5/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.5/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.6/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.6/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.7/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.7/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.8/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.8/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.9/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/0.9/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.0/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.0/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.1/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.1/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.2/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.2/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.3/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.3/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.4/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.4/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.5/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.5/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.6/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.6/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.7/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.7/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.8/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.8/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.9/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/1.9/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.0/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.0/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.1/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.1/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.2/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.2/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.3/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.3/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.4/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.4/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.5/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.5/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.6/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.6/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.7/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.7/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.8/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.8/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.9/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/2.9/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/3.0/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/3.0/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/3.1/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/3.1/RM/x']
# ['alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/3.2/RM/P', 'alpha2-3rd_C700/Heesen11/dirty/Piro18/wind/3.2/RM/x']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a74df73f4d12> in <module>
#      23             tmp['IGM'] = [ "%s_C%.0f" % ( model, f_IGM*1000 ) ]
#      24             print(tmp)
# ---> 25             bayes_mock[i_p,i_a,i_f] = BayesFactorCombined( DMs=DMs, RMs=RMs, scenario1=tmp, scenario2=scenario0, population=population, telescope=telescope)
#      26
#      27
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.6/site-packages/PreFRBLE/likelihood.py in BayesFactorCombined(DMs, RMs, zs, scenario1, scenario2, taus, population, telescope, which_NaN, L0, force, force_full)
#     446
#     447     """
# --> 448     L1 = LikelihoodCombined( DMs=DMs, RMs=RMs, zs=zs, scenario=scenario1, taus=taus, population=population, telescope=telescope, force=force )
#     449     L2 = LikelihoodCombined( DMs=DMs, RMs=RMs, zs=zs, scenario=scenario2, taus=taus, population=population, telescope=telescope, force=force_full ) if L0 is None else L0
#     450     ratio =  L1/L2
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.6/site-packages/PreFRBLE/likelihood.py in LikelihoodCombined(DMs, RMs, zs, taus, scenario, prior, population, telescope, force)
#     401         ## estimate likelihood of scenario based on RM, using the redshift likelihood as a prior
#     402         ##  sum results of all possible redshifts
# --> 403         P, x = GetLikelihood_Full( redshift=redshift, measure='RM', force=force, **scenario )
#     404         P, x = LikelihoodMeasureable( x=x, P=P, min=RM_min )
#     405 #        P, x = LikelihoodMeasureable( min=RM_min, typ='RM', redshift=redshift, density=False, **scenario )
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.6/site-packages/PreFRBLE/likelihood.py in GetLikelihood_Full(redshift, measure, force, **scenario)
#     607         except:
#     608             pass
# --> 609     return LikelihoodFull( measure=measure, redshift=redshift, **scenario )
#     610
#     611 def GetLikelihood_Telescope( telescope='Parkes', population='SMD', measure='DM', force=False, **scenario ):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.6/site-packages/PreFRBLE/likelihood.py in LikelihoodFull(measure, redshift, nside_IGM, **scenario)
#     231     if len(Ps) == 0:
#     232         sys.exit( "you must provide a reasonable scenario" )
# --> 233     P, x = LikelihoodsConvolve( Ps, xs, absolute= measure == 'RM' )
#     234
#     235     ## write to file
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.6/site-packages/PreFRBLE/likelihood.py in LikelihoodsConvolve(Ps, xs, **kwargs)
#     197     i = 0.
#     198     for P_, x_ in zip( Ps[1:], xs[1:] ):
# --> 199         P, x = LikelihoodConvolve( P, x, P_, x_, **kwargs )
#     200         i += 1
#     201         P /= np.sum( P*np.diff(x) )
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.6/site-packages/PreFRBLE/likelihood.py in LikelihoodConvolve(f, x_f, g, x_g, shrink, log, absolute)
#     170         for j in range( len(g) ):
#     171     ##   for each entry, find the corresponding range in M_x
# --> 172             in_ = np.where( x == M_x[i][j] )[0][0]
#     173             out = np.where( x == M_x[i+1][j+1] )[0][0]
#     174     ##   and add probability to convolved probability in that range
#
# KeyboardInterrupt:

# %% [markdown]
# assuming $f_{\rm IGM} = 0.9$ and SMD, use mock catalogs of increasing size to see how many FRBs at CHIME are required at least to identify strongest possible IGMF.

# %%
f_IGM = 0.9
population = 'SMD'
telescope = 'CHIME'

scenario_test = {
    'IGM' : ['primordial'],
    'Host': ['Heesen11/dirty'],
    'Local': ['Piro18/wind'], 
}

scenario_ref = scenario_test.copy()
#scenario_ref = scenario_IGM.copy()
scenario_ref['IGM'] = ['alpha1-3rd_C%.0f' % (f_IGM*1000)]

print( scenario_ref)

N_N = 10

Ns = (10.**np.linspace(1,3,N_N)).astype('i')

tries = 3 # number of repetitions to obtain error on bayes factors

measureable = True # consider that RM < RM_min are not observable?

Bayes = np.zeros( [ len(alphas), len(Ns) ] )
Bayes_std = np.zeros( [ 2, len(alphas), len(Ns) ] )

#for i_N, N in enumerate(Ns):
for i_N in trange(len(Ns )):
    N = Ns[i_N]
    bayes = np.zeros( [ len( alphas ), tries ] )
    for i in range(tries):
#        FRBs_mock = FakeFRBs( measureable=False, measures=['DM','RM'], N=50, telescope=telescope, population=population, **scenario_ref )# **scenario0 )
        FRBs_mock = FakeFRBs( measures=['DM','RM'], N=N, telescope=telescope, population=population, measureable=measureable, **scenario_ref )# **scenario0 )
        DMs = FRBs_mock['DM']
        RMs = FRBs_mock['RM']
        zs = FRBs_mock['redshift']

    
        P0 = LikelihoodCombined( DMs=DMs, RMs=RMs, scenario=scenario_ref, telescope=telescope, population=population, measureable=measureable )
        for i_a, alpha in enumerate( alphas ):
            tmp = scenario_ref.copy()
            tmp['IGM'] = [ "alpha%.0f-3rd_C%.0f" % ( alpha*3, f_IGM*1000 ) ]
#            print(tmp)
#            bayes[i_a,i] = BayesFactorCombined( DMs=DMs, RMs=RMs, scenario1=tmp, scenario2=scenario0, population=population, telescope=telescope)
            bayes[i_a,i] = np.prod( LikelihoodCombined( DMs=DMs, RMs=RMs, scenario=tmp, telescope=telescope, population=population, measureable=measureable ) / P0 )

    Bayes[:,i_N], Bayes_std[:,:,i_N] = LogMeanStd( bayes, axis=1 )
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# {'IGM': ['alpha1-3rd_C900'], 'Local': ['Piro18/wind'], 'Host': ['Heesen11/dirty']}
# {'IGM': ['alpha1-3rd_C900'], 'Local': ['Piro18/wind'], 'Host': ['Heesen11/dirty']}
# {'IGM': ['alpha2-3rd_C900'], 'Local': ['Piro18/wind'], 'Host': ['Heesen11/dirty']}
# {'IGM': ['alpha3-3rd_C900'], 'Local': ['Piro18/wind'], 'Host': ['Heesen11/dirty']}
# {'IGM': ['alpha4-3rd_C900'], 'Local': ['Piro18/wind'], 'Host': ['Heesen11/dirty']}
# {'IGM': ['alpha5-3rd_C900'], 'Local': ['Piro18/wind'], 'Host': ['Heesen11/dirty']}
# {'IGM': ['alpha6-3rd_C900'], 'Local': ['Piro18/wind'], 'Host': ['Heesen11/dirty']}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-05ef52a835ac> in <module>()
#      44             print(tmp)
#      45 #            bayes[i_a,i] = BayesFactorCombined( DMs=DMs, RMs=RMs, scenario1=tmp, scenario2=scenario0, population=population, telescope=telescope)
# ---> 46             bayes[i_a,i] = np.prod( LikelihoodCombined( DMs=DMs, RMs=RMs, scenario=tmp, telescope=telescope, population=population, measureable=measureable ) / P0 )
#      47
#      48     Bayes[:,i_N], Bayes_std[:,:,i_N] = LogMeanStd( bayes, axis=1 )
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in LikelihoodCombined(DMs, RMs, zs, taus, scenario, prior, population, telescope, measureable, force)
#     436         ## estimate likelihood of scenario based on RM, using the redshift likelihood as a prior
#     437         ##  sum results of all possible redshifts
# --> 438         P, x = GetLikelihood_Full( redshift=redshift, measure='RM', force=force, **scenario )
#     439         if measureable:
#     440             P, x = LikelihoodMeasureable( x=x, P=P, min=RM_min )
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in GetLikelihood_Full(redshift, measure, force, **scenario)
#     643             with h5.File( likelihood_file_Full, 'r' ) as f:
#     644 #                print( [ KeyFull( measure=measure, axis=axis, redshift=redshift, **scenario ) for axis in ['P', 'x'] ] )
# --> 645                 return [ f[ KeyFull( measure=measure, axis=axis, redshift=redshift, **scenario ) ][()] for axis in ['P', 'x'] ]
#     646         except:
#     647             pass
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in LikelihoodFull(measure, redshift, nside_IGM, **scenario)
#     264     if len(Ps) == 0:
#     265         sys.exit( "you must provide a reasonable scenario" )
# --> 266     P, x = LikelihoodsConvolve( Ps, xs, absolute= measure == 'RM' )
#     267
#     268     ## write to file
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in LikelihoodsConvolve(Ps, xs, **kwargs)
#     222     i = 0.
#     223     for P_, x_ in zip( Ps[1:], xs[1:] ):
# --> 224         P, x = LikelihoodConvolve( P, x, P_, x_, **kwargs )
#     225         i += 1
#     226         P /= np.sum( P*np.diff(x) )
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in LikelihoodConvolve(f, x_f, g, x_g, shrink, log, absolute)
#     199     ##   for each entry, find the corresponding range in M_x
#     200             in_ = np.where( x == M_x[i][j] )[0][0]
# --> 201             out = np.where( x == M_x[i+1][j+1] )[0][0]
#     202     ##   and add probability to convolved probability in that range
#     203             P[in_:out] += M_p[i][j]
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots()
plt.loglog()
for i_a, color in enumerate( Rainbow(alphas) ):
    if i_a % 2:
        continue
    plt.errorbar( Ns, Bayes[i_a], yerr=Bayes_std[:,i_a], color=color )
Colorbar( alphas, label=r"$\alpha$" )
plt.xlabel( r"$N_{\rm FRB}$", fontdict={'size':18 } )
plt.ylabel( r"$\mathcal{B}$", fontdict={'size':18 } )
plt.ylim(1e-10,2)
PlotLimit(ax=ax, x=ax.get_xlim(), y=[1e-2,1e-2], lower_limit=False, label='decisive', shift_text_vertical=-7e-3)
plt.show()
# Out:
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/matplotlib/axes/_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))

# %%
# Out:
# (7.943282347242816, 1258.9254117941662)

# %%
with h5.File( likelihood_file_IGM ) as f:
    print( f['primordial_C900/far/4/'].keys() )
# Out:
# <KeysViewHDF5 ['DM', 'RM', '|RM|']>
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/ipykernel_launcher.py:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   """Entry point for launching an IPython kernel.

# %%
bayes_mock
#LikelihoodObservedMeasure( Measures=RMs, measure='RM', scenario={'IGM':['alpha1-3rd_C900']}, telescope=telescope, population=population, plot=True, plot_FRBs=True, title=r"CHIME mock sample", use_localized=False )

# %%
for i_b, b in enumerate( bayes_mock ):
    fig, ax = plt.subplots()
    PlotBayes2D( bayes=b, y=alphas, x=f_IGMs, ylabel=r"$\alpha$", xlabel=r"$f_{\rm IGM}$", ax=ax, plane=True )
    ax.set_title( 'mock CHIME results, N=%i, %s' % (N, populations[i_b]) )
    plt.show()

# %% [markdown]
# perform joint analysis using events in FRBcat

# %%
bayes = np.zeros( [ len(populations), len(telescopes), len(models_IGM[3:]), len(f_IGMs) ] )

#for i_p, population in enumerate( populations ):
for i_p in trange( len(populations) ):
    population = populations[i_p]
    for i_t, telescope in enumerate( telescopes ):
        FRBs = GetFRBcat( telescopes=[telescope] )
        DMs = GetFRBsMeasures( measure='DM', FRBs=FRBs)
        RMs = GetFRBsMeasures( measure='RM', FRBs=FRBs)
        L0 = LikelihoodCombined( DMs=DMs, RMs=RMs, scenario=scenario0, telescope=telescope, population=population )
        for i_a, model in enumerate( models_IGM[3:] ):
            for i_f, f_IGM in enumerate( f_IGMs ):
                tmp = scenario_test.copy()
                tmp['IGM'] = [ "%s_C%.0f" % ( model, f_IGM*1000 ) ]
#                print(tmp)
                bayes[i_p,i_t,i_a,i_f] = BayesFactorCombined( DMs=DMs, RMs=RMs, scenario1=tmp, scenario2=scenario0, population=population, telescope=telescope)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f9bcc0a6333e> in <module>()
#      14                 tmp['IGM'] = [ "%s_C%.0f" % ( model, f_IGM*1000 ) ]
#      15 #                print(tmp)
# ---> 16                 bayes[i_p,i_t,i_a,i_f] = BayesFactorCombined( DMs=DMs, RMs=RMs, scenario1=tmp, scenario2=scenario0, population=population, telescope=telescope)
#      17
#      18
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in BayesFactorCombined(DMs, RMs, zs, scenario1, scenario2, taus, population, telescope, which_NaN, L0, force, force_full)
#     479
#     480     """
# --> 481     L1 = LikelihoodCombined( DMs=DMs, RMs=RMs, zs=zs, scenario=scenario1, taus=taus, population=population, telescope=telescope, force=force )
#     482     L2 = LikelihoodCombined( DMs=DMs, RMs=RMs, zs=zs, scenario=scenario2, taus=taus, population=population, telescope=telescope, force=force_full ) if L0 is None else L0
#     483     ratio =  L1/L2
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in LikelihoodCombined(DMs, RMs, zs, taus, scenario, prior, population, telescope, force)
#     434         ## estimate likelihood of scenario based on RM, using the redshift likelihood as a prior
#     435         ##  sum results of all possible redshifts
# --> 436         P, x = GetLikelihood_Full( redshift=redshift, measure='RM', force=force, **scenario )
#     437         P, x = LikelihoodMeasureable( x=x, P=P, min=RM_min )
#     438 #        P, x = LikelihoodMeasureable( min=RM_min, typ='RM', redshift=redshift, density=False, **scenario )
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in GetLikelihood_Full(redshift, measure, force, **scenario)
#     640         except:
#     641             pass
# --> 642     return LikelihoodFull( measure=measure, redshift=redshift, **scenario )
#     643
#     644 def GetLikelihood_Telescope( telescope='Parkes', population='SMD', measure='DM', force=False, **scenario ):
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in LikelihoodFull(measure, redshift, nside_IGM, **scenario)
#     264     if len(Ps) == 0:
#     265         sys.exit( "you must provide a reasonable scenario" )
# --> 266     P, x = LikelihoodsConvolve( Ps, xs, absolute= measure == 'RM' )
#     267
#     268     ## write to file
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in LikelihoodsConvolve(Ps, xs, **kwargs)
#     222     i = 0.
#     223     for P_, x_ in zip( Ps[1:], xs[1:] ):
# --> 224         P, x = LikelihoodConvolve( P, x, P_, x_, **kwargs )
#     225         i += 1
#     226         P /= np.sum( P*np.diff(x) )
#
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/PreFRBLE/likelihood.py in LikelihoodConvolve(f, x_f, g, x_g, shrink, log, absolute)
#     199     ##   for each entry, find the corresponding range in M_x
#     200             in_ = np.where( x == M_x[i][j] )[0][0]
# --> 201             out = np.where( x == M_x[i+1][j+1] )[0][0]
#     202     ##   and add probability to convolved probability in that range
#     203             P[in_:out] += M_p[i][j]
#
# KeyboardInterrupt:

# %%
bayes = 10**( -2-5*np.random.rand(  len(populations), len(telescopes), len(alphas), len(f_IGMs)  ) )

bayes[:,:,3:5,3:5] *= 1000

# %%
#fig, axss = plt.subplots( len(populations), len(telescopes), figsize=(4*len(populations), 3*(1+len(telescopes)) ) )
#for i_t, (telescope, axs) in enumerate( zip( telescopes, axss) ):
for i_t, telescope in enumerate( telescopes ):
#    fig, axs = plt.subplots( 1, len(populations), figsize=(4*len(populations),3 ) )
    fig, axs = plt.subplots( len(populations), 1, figsize=(4, len(populations)*3 ) )
    for i_p, (population, ax) in enumerate( zip(populations, axs) ):
        PlotBayes2D( P_min=1e-3, bayes=bayes[i_p,i_t], y=alphas, x=f_IGMs, ylabel=r"$\alpha$", xlabel=r"$f_{\rm IGM}$", ax=ax, plane=True )
        ax.set_title( '%s with %s' % (population, labels[telescope]))
    fig.tight_layout()

posterior_fIGM = np.genfromtxt("posterior_fIGM.npy").reshape(len(populations),len(f_IGMs))
prior_alpha = np.ones( len( alphas ) )

## posterior only for Parkes
posterior = bayes[:,-1] * prior_alpha.reshape([1,len(alphas),1]) * posterior_fIGM.reshape( [len(populations),1,len(f_IGMs)] )  

fig, axs = plt.subplots( 1, len(populations), figsize=(4*len(populations), 3 ) )
for i_p, (population, ax) in enumerate( zip(populations, axs) ):
    PlotBayes2D( P_min=1e-3, bayes=posterior[i_p], y=alphas, x=f_IGMs, ylabel=r"$\alpha$", xlabel=r"$f_{\rm IGM}$", ax=ax, plane=True, posterior=True )
    ax.set_title( '%s with Parkes' % population)
fig.tight_layout()




B = np.prod( bayes, axis=1 )
fig, axs = plt.subplots( 1, len(populations), figsize=(4*len(populations), 3 ) )
for i_p, (population, ax) in enumerate( zip(populations, axs) ):
    PlotBayes2D( P_min=1e-3, bayes=B[i_p], y=alphas, x=f_IGMs, ylabel=r"$\alpha$", xlabel=r"$f_{\rm IGM}$", ax=ax, plane=True )
    ax.set_title( '%s combined' % population)
fig.tight_layout()

posterior = B * prior_alpha.reshape([1,len(alphas),1]) * posterior_fIGM.reshape( [len(populations),1,len(f_IGMs)] )  

#fig, axs = plt.subplots( 1, len(populations), figsize=(4*len(populations), 3 ) )
fig, axs = plt.subplots( len(populations), 1, figsize=(4, len(populations)*3 ) )
for i_p, (population, ax) in enumerate( zip(populations, axs) ):
    PlotBayes2D( P_min=1e-3, bayes=posterior[i_p], y=alphas, x=f_IGMs, ylabel=r"$\alpha$", xlabel=r"$f_{\rm IGM}$", ax=ax, plane=True, posterior=True )
    ax.set_title( '%s combined' % population)
fig.tight_layout()

# %%
FRBs = GetFRBcat( telescopes=telescopes)

# %%
FRBs[np.abs(FRBs['RM'])>0]
# Out:
# /data/PreFRBLE/venv_PreFRBLE/lib/python3.4/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.
# array([('FRB181112',  589.27, 102. ,   10.9,  nan, 0.4755, 'ASKAP'),
#        ('FRB180924',  361.42,  40.5,   14. ,  nan, 0.3214, 'ASKAP'),
#        ('FRB180916',  349.2 , 200. , -114.6,  nan,    nan, 'CHIME/FRB'),
#        ('FRB180714', 1467.92, 257. ,  -25.9,  nan,    nan, 'parkes'),
#        ('FRB180311', 1570.9 ,  45.2,    4.8,  nan,    nan, 'parkes'),
#        ('FRB171209', 1457.4 ,  13. ,  121.6, 0.66,    nan, 'parkes'),
#        ('FRB160102', 2596.1 ,  13. , -220.6, 4.  ,    nan, 'parkes'),
#        ('FRB150807',  266.5 ,  36.9,   12. ,  nan,    nan, 'parkes'),
#        ('FRB150418',  776.2 , 188.5,   36. ,  nan,    nan, 'parkes'),
#        ('FRB150215', 1105.6 , 427.2,    1.5,  nan,    nan, 'parkes')],
#       dtype=[('ID', '<U9'), ('DM', '<f4'), ('DM_gal', '<f4'), ('RM', '<f4'), ('tau', '<f4'), ('host_redshift', '<f4'), ('tele', '<U10')])
