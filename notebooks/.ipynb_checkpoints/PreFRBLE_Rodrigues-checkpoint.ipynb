# %%
import matplotlib
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt

# %%
def Schechter( M, M_star=1, phi1=1, alpha1=1, phi2=1, alpha2=1):
    return ( phi1 * ( M / M_star )**alpha1 + phi2 * ( M / M_star )**alpha2 ) * np.exp( -M/M_star ) / M_star

# %%
## Best fit parameters from Davidzon et al. 2017, Tab. 1, redshifts are extended to z=0 and z=6
parameters = np.genfromtxt( 'COSMOS2015_Schechter_fit.txt', names=True)
parameters['M_star'] = 10.**parameters['M_star']

# %%
Ms = 10.**np.linspace(9,12,101)
dMs = np.diff(Ms)
n_gal = []
for p in parameters:
    phi = Schechter( Ms, M_star=p['M_star'], phi1=p['phi1'], alpha1=p['alpha1'], phi2=p['phi2'], alpha2=p['alpha2']) 
    n_gal.append( np.sum( phi[:-1]*dMs ) )
    plt.loglog( Ms[:-1]+dMs/2, phi[:-1]*dMs, label='%.1f < z < %.1f' % ( p['z0'], p['z1'] ) )
plt.legend()
plt.xlabel('$M/M_\odot$')
plt.ylabel('$\Phi/dex^{-1}/Mpc^{-3}$')
#plt.ylim(10.**-6.3, 10.**-1.8)
plt.show()

plt.plot( parameters['z1'], n_gal )
plt.ylabel('$n_{gal}$ / Mpc$^{-3}$')
plt.xlabel('redshift')
plt.show()

# %%
parameters
# Out:
# array([( 0. ,  0.5,   6.02559586e+10, -1.38,  1.187, -0.43,  1.92),
#        ( 0.5,  0.8,   5.88843655e+10, -1.36,  1.07 ,  0.03,  1.68),
#        ( 0.8,  1.1,   3.63078055e+10, -1.31,  1.428,  0.51,  2.19),
#        ( 1.1,  1.5,   4.16869383e+10, -1.28,  1.069,  0.29,  1.21),
#        ( 1.5,  2. ,   3.23593657e+10, -1.28,  0.969,  0.82,  0.64),
#        ( 2. ,  2.5,   3.98107171e+10, -1.57,  0.295,  0.07,  0.45),
#        ( 2.5,  3. ,   3.89045145e+10, -1.67,  0.228, -0.08,  0.21),
#        ( 3. ,  3.5,   6.76082975e+10, -1.76,  0.09 ,  0.  ,  0.  ),
#        ( 3.5,  4.5,   1.25892541e+11, -1.98,  0.016,  0.  ,  0.  ),
#        ( 4.5,  6. ,   1.99526231e+11, -2.11,  0.003,  0.  ,  0.  )],
#       dtype=[('z0', '<f8'), ('z1', '<f8'), ('M_star', '<f8'), ('alpha1', '<f8'), ('phi1', '<f8'), ('alpha2', '<f8'), ('phi2', '<f8')])
